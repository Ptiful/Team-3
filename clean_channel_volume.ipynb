# %%
import pandas as pd
import datetime

# %%
df = pd.read_csv("data_old/Channel_Volume.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8468 entries, 0 to 8467
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Location          8468 non-null   int64
#  1   Industry          8468 non-null   object
#  2   Edition           8468 non-null   int64
#  3   Category          8464 non-null   object
#  4   Subcategory       8468 non-null   object
#  5   Hierarchy_Level   8468 non-null   int64
#  6   Data_Type         8468 non-null   object
#  7   Outlet            8468 non-null   object
#  8   Outlet_Hierarchy  8468 non-null   int64
#  9   Unit              8468 non-null   object
#  10  Year_text         8468 non-null   int64
#  11  Year_date         8468 non-null   object
#  12  Volume            8468 non-null   object
# dtypes: int64(5), object(8)
# memory usage: 860.2+ KB

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Location, Industry, Edition, Category, Subcategory, Hierarchy_Level, Data_Type, Outlet, Outlet_Hierarchy, Unit, Year_text, Year_date, Volume]
# Index: []

# %%
df.isnull().sum()
# Out:
# Location            0
# Industry            0
# Edition             0
# Category            4
# Subcategory         0
# Hierarchy_Level     0
# Data_Type           0
# Outlet              0
# Outlet_Hierarchy    0
# Unit                0
# Year_text           0
# Year_date           0
# Volume              0
# dtype: int64

# %%
df[df['Category'].isnull()]
# Out:
#       Location          Industry  Edition Category  Subcategory
# 603          6  Alcoholic Drinks     2022      NaN         Wine  \
# 1974         3  Alcoholic Drinks     2022      NaN         Beer
# 2986         5  Alcoholic Drinks     2022      NaN  Cider/Perry
# 7547         5  Alcoholic Drinks     2022      NaN  Cider/Perry
#
#       Hierarchy_Level         Data_Type                   Outlet
# 603                 1  Off-trade Volume  Small Grocery Retailers  \
# 1974                1  Off-trade Volume             Hypermarkets
# 2986                1  Off-trade Volume          Warehouse Clubs
# 7547                1  Off-trade Volume      Non-Store Retailing
#
#       Outlet_Hierarchy            Unit  Year_text                  Year_date
# 603                  3  million litres       2010   Friday, 31 December 2010  \
# 1974                 3  million litres       2019  Tuesday, 31 December 2019
# 2986                 3      000 litres       2010   Friday, 31 December 2010
# ...

# %%
df[df["Subcategory"] == 'Wine'].head()
# Out:
#      Location          Industry  Edition Category Subcategory
# 420         1  Alcoholic Drinks     2022     Wine        Wine  \
# 421         1  Alcoholic Drinks     2022     Wine        Wine
# 422         1  Alcoholic Drinks     2022     Wine        Wine
# 423         1  Alcoholic Drinks     2022     Wine        Wine
# 424         1  Alcoholic Drinks     2022     Wine        Wine
#
#      Hierarchy_Level         Data_Type                          Outlet
# 420                1  Off-trade Volume  Food/drink/tobacco specialists  \
# 421                1  Off-trade Volume  Food/drink/tobacco specialists
# 422                1  Off-trade Volume  Food/drink/tobacco specialists
# 423                1  Off-trade Volume  Food/drink/tobacco specialists
# 424                1  Off-trade Volume  Food/drink/tobacco specialists
#
#      Outlet_Hierarchy            Unit  Year_text                    Year_date
# 420                 3  million litres       2007     Monday, 31 December 2007  \
# ...

# %%
df[df["Subcategory"] == 'Beer'].head()
# Out:
#    Location          Industry  Edition Category Subcategory  Hierarchy_Level
# 0         1  Alcoholic Drinks     2022     Beer        Beer                1  \
# 1         1  Alcoholic Drinks     2022     Beer        Beer                1
# 2         1  Alcoholic Drinks     2022     Beer        Beer                1
# 3         1  Alcoholic Drinks     2022     Beer        Beer                1
# 4         1  Alcoholic Drinks     2022     Beer        Beer                1
#
#           Data_Type                          Outlet  Outlet_Hierarchy
# 0  Off-trade Volume  Food/drink/tobacco specialists                 3  \
# 1  Off-trade Volume  Food/drink/tobacco specialists                 3
# 2  Off-trade Volume  Food/drink/tobacco specialists                 3
# 3  Off-trade Volume  Food/drink/tobacco specialists                 3
# 4  Off-trade Volume  Food/drink/tobacco specialists                 3
#
#              Unit  Year_text                    Year_date       Volume
# ...

# %%
df[df["Subcategory"] == 'Cider/Perry'].head()
# Out:
#      Location          Industry  Edition     Category  Subcategory
# 105         1  Alcoholic Drinks     2022  Cider/Perry  Cider/Perry  \
# 106         1  Alcoholic Drinks     2022  Cider/Perry  Cider/Perry
# 107         1  Alcoholic Drinks     2022  Cider/Perry  Cider/Perry
# 108         1  Alcoholic Drinks     2022  Cider/Perry  Cider/Perry
# 109         1  Alcoholic Drinks     2022  Cider/Perry  Cider/Perry
#
#      Hierarchy_Level         Data_Type                          Outlet
# 105                1  Off-trade Volume  Food/drink/tobacco specialists  \
# 106                1  Off-trade Volume  Food/drink/tobacco specialists
# 107                1  Off-trade Volume  Food/drink/tobacco specialists
# 108                1  Off-trade Volume  Food/drink/tobacco specialists
# 109                1  Off-trade Volume  Food/drink/tobacco specialists
#
#      Outlet_Hierarchy        Unit  Year_text                    Year_date
# ...

# %%
df.Category.fillna(df["Subcategory"], inplace=True)

# %%
df[df['Category'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Location, Industry, Edition, Category, Subcategory, Hierarchy_Level, Data_Type, Outlet, Outlet_Hierarchy, Unit, Year_text, Year_date, Volume]
# Index: []

# %%
df.Unit.unique()
# Out:
# array(['million litres', '000 litres'], dtype=object)

# %%
pd.to_datetime(df["Year_text"])
# Out:
# 0      1970-01-01 00:00:00.000002007
# 1      1970-01-01 00:00:00.000002008
# 2      1970-01-01 00:00:00.000002009
# 3      1970-01-01 00:00:00.000002010
# 4      1970-01-01 00:00:00.000002011
#                     ...
# 8463   1970-01-01 00:00:00.000002017
# 8464   1970-01-01 00:00:00.000002018
# 8465   1970-01-01 00:00:00.000002019
# 8466   1970-01-01 00:00:00.000002020
# 8467   1970-01-01 00:00:00.000002021
# Name: Year_text, Length: 8468, dtype: datetime64[ns]
